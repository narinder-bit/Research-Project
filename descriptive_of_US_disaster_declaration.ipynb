# %% [markdown]
# <a href="https://colab.research.google.com/github/narinder-bit/HTML-CSS/blob/main/descriptive_of_US_disaster_declaration.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd # data processing, CSV file
import requests
import os
import os


csv_files = ['/content/us_disaster_declarations.csv', '/content/us_disasters_m5.csv']

for csv_file in csv_files:
    dirname = os.path.dirname(csv_file)
    filename = os.path.basename(csv_file)
    print("Directory:", dirname)
    print("CSV File:", filename)
# Out:
# Directory: /content
# CSV File: us_disaster_declarations.csv
# Directory: /content
# CSV File: us_disasters_m5.csv

# %%
disaster_fun = "/content/us_disaster_declarations.csv"
disaster_datacard = pd.read_csv(disaster_fun)

print(disaster_datacard.shape)
print(disaster_datacard.sample(5))
# Out:
# (3705, 23)
#      fema_declaration_string  disaster_number state declaration_type  \
# 106                DR-109-AL              109    AL               DR
# 413                DR-192-WI              192    WI               DR
# 3030               DR-375-AR              375    AR               DR
# 448                DR-193-IA              193    IA               DR
# 3310               DR-396-CO              396    CO               DR
#
#           declaration_date  fy_declared incident_type  \
# 106   1961-02-27T00:00:00Z         1961         Flood
# 413   1965-04-21T00:00:00Z         1965       Tornado
# 3030  1973-04-27T00:00:00Z         1973         Flood
# 448   1965-04-22T00:00:00Z         1965         Flood
# 3310  1973-07-06T00:00:00Z         1973         Flood
#
#                         declaration_title  ih_program_declared  \
# 106                                Floods                    0
# 413   Tornadoes, Severe Storms & Flooding                    0
# 3030             Severe Storms & Flooding                    0
# 448                              Flooding                    0
# 3310                Flooding & Landslides                    0
#
#       ia_program_declared  ...     incident_end_date  disaster_closeout_date  \
# 106                     1  ...  1961-02-27T00:00:00Z    1962-08-22T00:00:00Z
# 413                     1  ...  1965-04-21T00:00:00Z    1967-09-05T00:00:00Z
# 3030                    1  ...  1973-04-27T00:00:00Z    1976-02-13T00:00:00Z
# 448                     1  ...  1965-04-22T00:00:00Z    1970-01-29T00:00:00Z
# 3310                    0  ...  1973-07-06T00:00:00Z    1976-09-16T00:00:00Z
#
#        fips place_code       designated_area  declaration_request_number  \
# 106    1000          0             Statewide                     61010.0
# 413   55003      99003      Ashland (County)                     65018.0
# 3030   5123      99123  St. Francis (County)                     73037.0
# 448   19045      99045      Clinton (County)                     65019.0
# 3310   8007      99007    Archuleta (County)                     73064.0
#
#       last_ia_filing_date          last_refresh  \
# 106                   NaN  2023-03-18T13:22:03Z
# 413                   NaN  2023-03-18T13:22:03Z
# 3030                  NaN  2023-03-18T13:22:03Z
# 448                   NaN  2023-03-18T13:22:03Z
# 3310                  NaN  2023-03-18T13:22:03Z
#
#                                           hash  \
# 106   96bd34a90feee07f44a27fea4d9a5d7fceb5796b
# 413   ed69b9e01de99c63908612dbf3156733f06d62ea
# 3030  a6f5adef8a08cff71a281d7e6260bc547250393c
# 448   957712cd0c2b8aa5db7c00e250acd6a80fc9f40d
# 3310  00e5841ccdd1f348c6089482a33988aef73bbf12
#
#                                         id
# 106   2b62071c-31f0-4ec4-9785-098083565d14
# 413   aaf770bf-3cbd-4a1a-8c27-802f70b510ad
# 3030  56f450e8-c712-4f14-aee9-2ddcee2d675c
# 448   360088dd-2cb9-488d-b349-bdf578708da0
# 3310  e3a94b74-6780-48b5-b4c0-7da2e31707d5
#
# [5 rows x 23 columns]

# %%
us5_fun = "/content/us_disasters_m5.csv"
disaster5_datacard = pd.read_csv(us5_fun)

print(disaster5_datacard.shape)
print(disaster5_datacard.sample(5))
# Out:
# (627, 14)
#      disaster_number state declaration_type      declaration_date  \
# 405             4223    TX               DR  2015-05-30T03:02:00Z
# 168             1999    TX               DR  2011-07-01T17:30:00Z
# 409             4223    TX               DR  2015-05-30T03:02:00Z
# 549             4266    TX               DR  2016-03-19T21:35:00Z
# 556             4269    TX               DR  2016-04-25T19:46:00Z
#
#        incident_type                                  declaration_title  \
# 405  Severe Storm(s)  Severe Storms, Tornadoes, Straight-Line Winds ...
# 168             Fire                                          Wildfires
# 409  Severe Storm(s)  Severe Storms, Tornadoes, Straight-Line Winds ...
# 549            Flood             Severe Storms, Tornadoes, And Flooding
# 556            Flood                         Severe Storms And Flooding
#
#      ih_program_declared  ia_program_declared  pa_program_declared  \
# 405                    1                    0                    1
# 168                    0                    0                    1
# 409                    1                    0                    0
# 549                    0                    0                    1
# 556                    1                    0                    1
#
#      hm_program_declared   incident_begin_date     incident_end_date   fips  \
# 405                    1  2015-05-04T04:00:00Z  2015-06-23T03:59:00Z  48037
# 168                    1  2011-04-06T04:00:00Z  2011-08-29T04:00:00Z  48445
# 409                    1  2015-05-04T04:00:00Z  2015-06-23T03:59:00Z  48157
# 549                    1  2016-03-07T05:00:00Z  2016-03-30T03:59:00Z  48067
# 556                    1  2016-04-17T04:00:00Z  2016-05-01T03:59:00Z  48089
#
#         designated_area
# 405      Bowie (County)
# 168      Terry (County)
# 409  Fort Bend (County)
# 549       Cass (County)
# 556   Colorado (County)

# %%
disaster_fun = "/content/us_disaster_declarations.csv"
us5_fun = "/content/us_disasters_m5.csv"

# Examine the CSV files.
disaster_datacard = pd.read_csv(disaster_fun)
disaster5_datacard = pd.read_csv(us5_fun)

# Present the form and samples.
print("Disaster Datacard Shape:", disaster_datacard.shape)
print("disaster5_datacard", disaster5_datacard.shape)

# Manifest the two DataFrames
print("Disaster Datacard Sample:")
print(disaster_datacard.sample(5))

print("disaster5_datacard:")
print(disaster5_datacard.sample(5))
# Out:
# Disaster Datacard Shape: (3705, 23)
# disaster5_datacard (627, 14)
# Disaster Datacard Sample:
#      fema_declaration_string  disaster_number state declaration_type  \
# 2074               DR-312-PA              312    PA               DR
# 2200               DR-328-WA              328    WA               DR
# 996                DR-228-NE              228    NE               DR
# 3618               DR-424-TN              424    TN               DR
# 3547               DR-413-OR              413    OR               DR
#
#           declaration_date  fy_declared incident_type  \
# 2074  1971-09-18T00:00:00Z         1971         Flood
# 2200  1972-03-24T00:00:00Z         1972         Flood
# 996   1967-07-18T00:00:00Z         1967         Flood
# 3618  1974-04-04T00:00:00Z         1974       Tornado
# 3547  1974-01-25T00:00:00Z         1974         Flood
#
#                        declaration_title  ih_program_declared  \
# 2074                              Floods                    0
# 2200              Heavy Rains & Flooding                    0
# 996             Severe Storms & Flooding                    0
# 3618                           Tornadoes                    0
# 3547  Severe Storms, Snowmelt & Flooding                    0
#
#       ia_program_declared  ...     incident_end_date  disaster_closeout_date  \
# 2074                    1  ...  1971-09-18T00:00:00Z    1981-04-16T00:00:00Z
# 2200                    1  ...  1972-03-24T00:00:00Z    1976-04-15T00:00:00Z
# 996                     1  ...  1967-07-18T00:00:00Z    1971-08-16T00:00:00Z
# 3618                    1  ...  1974-04-04T00:00:00Z    1977-05-31T00:00:00Z
# 3547                    1  ...  1974-01-25T00:00:00Z    1978-07-06T00:00:00Z
#
#        fips place_code      designated_area  declaration_request_number  \
# 2074  42091      99091  Montgomery (County)                     71053.0
# 2200  53067      99067    Thurston (County)                     72017.0
# 996   31173      99173    Thurston (County)                     67022.0
# 3618  47111      99111       Macon (County)                     74030.0
# 3547  41027      99027  Hood River (County)                     74009.0
#
#       last_ia_filing_date          last_refresh  \
# 2074                  NaN  2023-03-18T13:22:03Z
# 2200                  NaN  2023-03-18T13:22:03Z
# 996                   NaN  2023-03-18T13:22:03Z
# 3618                  NaN  2023-03-18T13:22:03Z
# 3547                  NaN  2023-03-18T13:22:03Z
#
#                                           hash  \
# 2074  8d46815a45baca9cd2e4965b106192f8a06cccfb
# 2200  2294fff760286f899263fa60d85d5d0c68324b02
# 996   d8bebd206656ad2d760a82213bb46c73c29e550f
# 3618  a34a12bcfbbf844af13dbd33c69a20c28c70c9f6
# 3547  167b96ab40875721beb7f67e4f6c918ab43ca6e7
#
#                                         id
# 2074  675ac32c-9043-4a12-a33e-8aab5b944ef0
# 2200  a74a821a-ccb1-4bd6-904c-fe4b2d9d0f5b
# 996   36edde07-0ba2-4337-ab9a-3aafff53e900
# 3618  515a71ed-3840-4533-90a5-5e01e1156ccd
# 3547  589d605c-094b-4960-aa4a-1525f3670397
#
# [5 rows x 23 columns]
# disaster5_datacard:
#      disaster_number state declaration_type      declaration_date  \
# 530             4255    TX               DR  2016-02-09T15:45:00Z
# 516             4255    TX               DR  2016-02-09T15:45:00Z
# 332             5082    CA               FM  2014-10-09T01:48:00Z
# 277             2970    CA               FM  2011-09-11T06:36:00Z
# 529             4255    TX               DR  2016-02-09T15:45:00Z
#
#        incident_type                                  declaration_title  \
# 530  Severe Storm(s)  Severe Winter Storms, Tornadoes, Straight-Line...
# 516  Severe Storm(s)  Severe Winter Storms, Tornadoes, Straight-Line...
# 332             Fire                                     Applegate Fire
# 277             Fire                                 Keene Fire Complex
# 529  Severe Storm(s)  Severe Winter Storms, Tornadoes, Straight-Line...
#
#      ih_program_declared  ia_program_declared  pa_program_declared  \
# 530                    0                    0                    1
# 516                    0                    0                    1
# 332                    0                    0                    1
# 277                    0                    0                    1
# 529                    0                    0                    1
#
#      hm_program_declared   incident_begin_date     incident_end_date   fips  \
# 530                    1  2015-12-26T05:00:00Z  2016-01-22T04:59:00Z  48379
# 516                    1  2015-12-26T05:00:00Z  2016-01-22T04:59:00Z  48129
# 332                    0  2014-10-08T04:00:00Z  2014-10-14T03:59:00Z   6061
# 277                    0  2011-09-10T21:15:28Z                   NaN   6029
# 529                    1  2015-12-26T05:00:00Z  2016-01-22T04:59:00Z  48387
#
#         designated_area
# 530      Rains (County)
# 516     Donley (County)
# 332     Placer (County)
# 277       Kern (County)
# 529  Red River (County)

# %%
disaster_fun = "/content/us_disaster_declarations.csv"
us5_fun = "/content/us_disasters_m5.csv"

# Examine the CSV files.

disaster_datacard = pd.read_csv(disaster_fun)
disaster5_datacard = pd.read_csv(us5_fun)

# based on a similar column, merge
merged_data = pd.merge(disaster_datacard, disaster5_datacard, on="incident_type")

# Display the combined shape and sample images.

print("Merged Data Shape:", merged_data.shape)
print("Merged Data Sample:")
print(merged_data.sample(5))
# Out:
# Merged Data Shape: (254443, 36)
# Merged Data Sample:
#        fema_declaration_string  disaster_number_x state_x declaration_type_x  \
# 234410               DR-409-OK                409      OK                 DR
# 68183                DR-248-IA                248      IA                 DR
# 38348                DR-203-MO                203      MO                 DR
# 157406               DR-339-VA                339      VA                 DR
# 84220                DR-255-MN                255      MN                 DR
#
#           declaration_date_x  fy_declared incident_type  \
# 234410  1973-12-10T00:00:00Z         1974         Flood
# 68183   1968-08-04T00:00:00Z         1968         Flood
# 38348   1965-07-27T00:00:00Z         1965         Flood
# 157406  1972-06-23T00:00:00Z         1972         Flood
# 84220   1969-04-18T00:00:00Z         1969         Flood
#
#              declaration_title_x  ih_program_declared_x  \
# 234410  Severe Storms & Flooding                      0
# 68183     Heavy Rains & Flooding                      0
# 38348   Severe Storms & Flooding                      0
# 157406      Tropical Storm Agnes                      0
# 84220                   Flooding                      0
#
#         ia_program_declared_x  ...    declaration_date_y  \
# 234410                      1  ...  2016-04-25T19:46:00Z
# 68183                       1  ...  2016-06-11T17:23:00Z
# 38348                       1  ...  2016-06-11T17:23:00Z
# 157406                      1  ...  2016-06-11T17:23:00Z
# 84220                       1  ...  2016-06-11T17:23:00Z
#
#                declaration_title_y ih_program_declared_y  \
# 234410  Severe Storms And Flooding                     1
# 68183   Severe Storms And Flooding                     0
# 38348   Severe Storms And Flooding                     0
# 157406  Severe Storms And Flooding                     1
# 84220   Severe Storms And Flooding                     1
#
#        ia_program_declared_y pa_program_declared_y  hm_program_declared_y  \
# 234410                     0                     1                      1
# 68183                      0                     1                      1
# 38348                      0                     1                      1
# 157406                     0                     1                      1
# 84220                      0                     0                      1
#
#         incident_begin_date_y   incident_end_date_y  fips_y  \
# 234410   2016-04-17T04:00:00Z  2016-05-01T03:59:00Z   48201
# 68183    2016-05-22T04:00:00Z  2016-06-25T03:59:00Z   48035
# 38348    2016-05-22T04:00:00Z  2016-06-25T03:59:00Z   48425
# 157406   2016-05-22T04:00:00Z  2016-06-25T03:59:00Z   48291
# 84220    2016-05-22T04:00:00Z  2016-06-25T03:59:00Z   48367
#
#          designated_area_y
# 234410     Harris (County)
# 68183      Bosque (County)
# 38348   Somervell (County)
# 157406    Liberty (County)
# 84220      Parker (County)
#
# [5 rows x 36 columns]

# %%
disaster_fun = "/content/us_disaster_declarations.csv"
us5_fun = "/content/us_disasters_m5.csv"

#Examine the CSV files.
disaster_datacard = pd.read_csv(disaster_fun)
disaster5_datacard = pd.read_csv(us5_fun)

# Combined the DataFrames into a single column.
merged_data = pd.merge(disaster_datacard, disaster5_datacard, on="incident_type")

# information about each DataFrame is displayed.
print("Disaster Datacard Info:")
print(disaster_datacard.info())

print("\nDisaster5 Datacard Info:")
print(disaster5_datacard.info())

print("\nMerged Data Info:")
print(merged_data.info())
# Out:
# Disaster Datacard Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3705 entries, 0 to 3704
# Data columns (total 23 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   fema_declaration_string     3705 non-null   object
#  1   disaster_number             3705 non-null   int64
#  2   state                       3705 non-null   object
#  3   declaration_type            3705 non-null   object
#  4   declaration_date            3705 non-null   object
#  5   fy_declared                 3705 non-null   int64
#  6   incident_type               3705 non-null   object
#  7   declaration_title           3705 non-null   object
#  8   ih_program_declared         3705 non-null   int64
#  9   ia_program_declared         3705 non-null   int64
#  10  pa_program_declared         3705 non-null   int64
#  11  hm_program_declared         3705 non-null   int64
#  12  incident_begin_date         3705 non-null   object
#  13  incident_end_date           3705 non-null   object
#  14  disaster_closeout_date      3705 non-null   object
#  15  fips                        3705 non-null   int64
#  16  place_code                  3705 non-null   int64
#  17  designated_area             3705 non-null   object
#  18  declaration_request_number  3704 non-null   float64
#  19  last_ia_filing_date         0 non-null      float64
#  20  last_refresh                3704 non-null   object
#  21  hash                        3704 non-null   object
#  22  id                          3704 non-null   object
# dtypes: float64(2), int64(8), object(13)
# memory usage: 665.9+ KB
# None
#
# Disaster5 Datacard Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 627 entries, 0 to 626
# Data columns (total 14 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   disaster_number      627 non-null    int64
#  1   state                627 non-null    object
#  2   declaration_type     627 non-null    object
#  3   declaration_date     627 non-null    object
#  4   incident_type        627 non-null    object
#  5   declaration_title    627 non-null    object
#  6   ih_program_declared  627 non-null    int64
#  7   ia_program_declared  627 non-null    int64
#  8   pa_program_declared  627 non-null    int64
#  9   hm_program_declared  627 non-null    int64
#  10  incident_begin_date  627 non-null    object
#  11  incident_end_date    616 non-null    object
#  12  fips                 627 non-null    int64
#  13  designated_area      627 non-null    object
# dtypes: int64(6), object(8)
# memory usage: 68.7+ KB
# None
#
# Merged Data Info:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 254443 entries, 0 to 254442
# Data columns (total 36 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   fema_declaration_string     254443 non-null  object
#  1   disaster_number_x           254443 non-null  int64
#  2   state_x                     254443 non-null  object
#  3   declaration_type_x          254443 non-null  object
#  4   declaration_date_x          254443 non-null  object
#  5   fy_declared                 254443 non-null  int64
#  6   incident_type               254443 non-null  object
#  7   declaration_title_x         254443 non-null  object
#  8   ih_program_declared_x       254443 non-null  int64
#  9   ia_program_declared_x       254443 non-null  int64
#  10  pa_program_declared_x       254443 non-null  int64
#  11  hm_program_declared_x       254443 non-null  int64
#  12  incident_begin_date_x       254443 non-null  object
#  13  incident_end_date_x         254443 non-null  object
#  14  disaster_closeout_date      254443 non-null  object
#  15  fips_x                      254443 non-null  int64
#  16  place_code                  254443 non-null  int64
#  17  designated_area_x           254443 non-null  object
#  18  declaration_request_number  254443 non-null  float64
#  19  last_ia_filing_date         0 non-null       float64
#  20  last_refresh                254443 non-null  object
#  21  hash                        254443 non-null  object
#  22  id                          254443 non-null  object
#  23  disaster_number_y           254443 non-null  int64
#  24  state_y                     254443 non-null  object
#  25  declaration_type_y          254443 non-null  object
#  26  declaration_date_y          254443 non-null  object
#  27  declaration_title_y         254443 non-null  object
#  28  ih_program_declared_y       254443 non-null  int64
#  29  ia_program_declared_y       254443 non-null  int64
#  30  pa_program_declared_y       254443 non-null  int64
#  31  hm_program_declared_y       254443 non-null  int64
#  32  incident_begin_date_y       254443 non-null  object
#  33  incident_end_date_y         254058 non-null  object
#  34  fips_y                      254443 non-null  int64
#  35  designated_area_y           254443 non-null  object
# dtypes: float64(2), int64(14), object(20)
# memory usage: 71.8+ MB
# None

# %%
pip install seaborn matplotlib
# Out:
# Requirement already satisfied: seaborn in /usr/local/lib/python3.10/dist-packages (0.12.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (3.7.1)
# Requirement already satisfied: numpy!=1.24.0,>=1.17 in /usr/local/lib/python3.10/dist-packages (from seaborn) (1.23.5)
# Requirement already satisfied: pandas>=0.25 in /usr/local/lib/python3.10/dist-packages (from seaborn) (1.5.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (4.42.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.25->seaborn) (2022.7.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)

# %%
disaster_fun = "/content/us_disaster_declarations.csv"
us5_fun = "/content/us_disasters_m5.csv"

# Examine the CSV files.
disaster_datacard = pd.read_csv(disaster_fun)
disaster5_datacard = pd.read_csv(us5_fun)

# the DataFrames together
combined_data = pd.concat([disaster_datacard, disaster5_datacard])

# choosing columns for the pair plot
columns_pairplot = ['disaster_number', 'declaration_request_number', 'fips', 'fy_declared']

#  duo plot develop
sns.pairplot(combined_data[columns_pairplot])
plt.show()

# %%
dataframe1 = pd.read_csv('/content/us_disaster_declarations.csv')
dataframe2 = pd.read_csv('/content/us_disasters_m5.csv')

# For Dataset 1, certain disaster categories and their occurrences
disaster_types_df1 = dataframe1['incident_type'].unique()
print("Types of Disasters reported in DataFrame 1:\n\n", disaster_types_df1)

print("Occurrences in DataFrame 1:\n\n", dataframe1['incident_type'].value_counts())

# For Dataset 2, certain disaster categories and their occurrences
disaster_types_df2 = dataframe2['incident_type'].unique()
print("\nTypes of Disasters reported in DataFrame 2:\n\n", disaster_types_df2)

print("Occurrences in DataFrame 2:\n\n", dataframe2['incident_type'].value_counts())
# Out:
# Types of Disasters reported in DataFrame 1:
#
#  ['Tornado' 'Flood' 'Fire' 'Other' 'Earthquake' 'Hurricane'
#  'Volcanic Eruption' 'Severe Storm' 'Toxic Substances' 'Typhoon' 'Drought'
#  'Dam/Levee Break' 'Snowstorm' 'Severe Ice Storm' 'Freezing'
#  'Coastal Storm' 'Fishing Losses' 'Mud/Landslide']
# Occurrences in DataFrame 1:
#
#  Flood                2563
# Tornado               464
# Severe Storm          266
# Hurricane             219
# Drought                54
# Fire                   35
# Severe Ice Storm       21
# Fishing Losses         16
# Coastal Storm          15
# Earthquake             11
# Snowstorm              10
# Typhoon                10
# Other                   8
# Freezing                6
# Dam/Levee Break         2
# Toxic Substances        2
# Mud/Landslide           2
# Volcanic Eruption       1
# Name: incident_type, dtype: int64
#
# Types of Disasters reported in DataFrame 2:
#
#  ['Fire' 'Snow' 'Tsunami' 'Severe Storm(s)' 'Other' 'Earthquake' 'Flood']
# Occurrences in DataFrame 2:
#
#  Fire               312
# Severe Storm(s)    202
# Flood               95
# Snow                11
# Tsunami              3
# Other                2
# Earthquake           2
# Name: incident_type, dtype: int64

# %%
#Check out two datasets
disaster_datacard = pd.read_csv('/content/us_disaster_declarations.csv')
disaster5_datacard = pd.read_csv('/content/us_disasters_m5.csv')

# assemble the data set.
combined_data = pd.concat([disaster_datacard, disaster5_datacard])

# Set the appropriate time zone by converting declaration_date to datetime format.

combined_data['declaration_date'] = pd.to_datetime(combined_data['declaration_date']).dt.tz_localize(None)

# List the different types of incidents.

incident_types = combined_data['incident_type'].unique()

# Create a dictionary from scratch to hold quarterly percentages for each sort of incidence.

quarterly_percentages = {}

# Determine quarterly percentages for each type of event.

for incident_type in incident_types:
    incident_type_data = combined_data[combined_data['incident_type'] == incident_type]
    quarter_totals = incident_type_data.groupby(pd.PeriodIndex(incident_type_data['declaration_date'], freq='Q')).size()
    total_all = quarter_totals.sum()
    percentages = [quarter_total / total_all * 100 for quarter_total in quarter_totals]
    quarterly_percentages[incident_type] = percentages

# Determine the quarterly percentages for each type of event.

quarterly_percentages = {}
for incident_type in incident_types:
    incident_type_data = combined_data[combined_data['incident_type'] == incident_type]
    quarter_totals = incident_type_data.groupby(incident_type_data['declaration_date'].dt.to_period('Q')).size()
    total_all = quarter_totals.sum()
    percentages = [quarter_total / total_all * 100 for quarter_total in quarter_totals]

    print(f"Incident Type: {incident_type}, Length of Percentages: {len(percentages)}")

    quarterly_percentages[incident_type] = percentages



# Determine quarterly percentages for each type of event.

for incident_type in incident_types:
    incident_type_data = combined_data[combined_data['incident_type'] == incident_type]
    quarter_totals = incident_type_data.groupby(incident_type_data['declaration_date'].dt.to_period('Q')).size()
    total_all = quarter_totals.sum()
    percentages = [quarter_total / total_all * 100 for quarter_total in quarter_totals]
    print(f"Incident Type: {incident_type}, Length of Percentages: {len(percentages)}")
    quarterly_percentages[incident_type] = percentages
# Out:
# Incident Type: Tornado, Length of Percentages: 20
# Incident Type: Flood, Length of Percentages: 69
# Incident Type: Fire, Length of Percentages: 25
# Incident Type: Other, Length of Percentages: 10
# Incident Type: Earthquake, Length of Percentages: 7
# Incident Type: Hurricane, Length of Percentages: 20
# Incident Type: Volcanic Eruption, Length of Percentages: 1
# Incident Type: Severe Storm, Length of Percentages: 11
# Incident Type: Toxic Substances, Length of Percentages: 1
# Incident Type: Typhoon, Length of Percentages: 5
# Incident Type: Drought, Length of Percentages: 3
# Incident Type: Dam/Levee Break, Length of Percentages: 2
# Incident Type: Snowstorm, Length of Percentages: 2
# Incident Type: Severe Ice Storm, Length of Percentages: 1
# Incident Type: Freezing, Length of Percentages: 1
# Incident Type: Coastal Storm, Length of Percentages: 2
# Incident Type: Fishing Losses, Length of Percentages: 1
# Incident Type: Mud/Landslide, Length of Percentages: 1
# Incident Type: Snow, Length of Percentages: 1
# Incident Type: Tsunami, Length of Percentages: 1
# Incident Type: Severe Storm(s), Length of Percentages: 6
# Incident Type: Tornado, Length of Percentages: 20
# Incident Type: Flood, Length of Percentages: 69
# Incident Type: Fire, Length of Percentages: 25
# Incident Type: Other, Length of Percentages: 10
# Incident Type: Earthquake, Length of Percentages: 7
# Incident Type: Hurricane, Length of Percentages: 20
# Incident Type: Volcanic Eruption, Length of Percentages: 1
# Incident Type: Severe Storm, Length of Percentages: 11
# Incident Type: Toxic Substances, Length of Percentages: 1
# Incident Type: Typhoon, Length of Percentages: 5
# Incident Type: Drought, Length of Percentages: 3
# Incident Type: Dam/Levee Break, Length of Percentages: 2
# Incident Type: Snowstorm, Length of Percentages: 2
# Incident Type: Severe Ice Storm, Length of Percentages: 1
# Incident Type: Freezing, Length of Percentages: 1
# Incident Type: Coastal Storm, Length of Percentages: 2
# Incident Type: Fishing Losses, Length of Percentages: 1
# Incident Type: Mud/Landslide, Length of Percentages: 1
# Incident Type: Snow, Length of Percentages: 1
# Incident Type: Tsunami, Length of Percentages: 1
# Incident Type: Severe Storm(s), Length of Percentages: 6

# %%
import matplotlib.pyplot as plt
import seaborn as sns

incident_type_order = [
    'Tornado', 'Flood', 'Fire', 'Other', 'Earthquake', 'Hurricane', 'Volcanic Eruption',
    'Severe Storm', 'Toxic Substances', 'Typhoon', 'Drought', 'Dam/Levee Break',
    'Severe Ice Storm', 'Freezing', 'Coastal Storm', 'Snowstorm', 'Fishing Losses',
    'Mud/Landslide', 'Human Cause', 'Terrorist', 'Biological', 'Tsunami'
]

plt.figure(figsize=(10, 6))
sns.set(style="whitegrid")
sns.countplot(data=combined_data, y='incident_type', order=incident_type_order)
plt.xlabel('Frequency')
plt.ylabel('Incident Type')
plt.title('Distribution of Incident Types')
plt.tight_layout()
plt.show()

# %% [markdown]
# natural catastrophes across time, plotted according to frequency and count

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Compute a summary of incident type statistics by fiscal year.

f = combined_data[['fy_declared', 'incident_type']].groupby('fy_declared').describe()['incident_type'].reset_index()

# Plot the bar plot
plt.figure(figsize=(9, 6))
sns.barplot(x='top', y='freq', data=f)
plt.xlabel('Incident Type')
plt.ylabel('Frequency')
plt.title('Top Incident Types per Fiscal Year')
plt.tight_layout()
plt.show()

# %%
# Compute a summary of incident type statistics by fiscal year.

d = combined_data['fy_declared'].value_counts().reset_index()
d.columns = ['fy_declared', 'incident_count']

# Show the top 10 fiscal years and the number of incidents for each year.

print(d.head(10))
# Out:
#    fy_declared  incident_count
# 0       1973.0             852
# 1       1965.0             545
# 2       1969.0             516
# 3       1972.0             494
# 4       1974.0             276
# 5       1971.0             230
# 6       1967.0             194
# 7       1970.0             149
# 8       1968.0             149
# 9       1966.0             124

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(x=m.index, y='fy_declared', data=m.sort_values(by='fy_declared'), marker='o', s=20)
plt.xlabel('Index')
plt.ylabel('Fiscal Year Declared')
plt.title('Incident Count by Fiscal Year')
plt.show()

# %% [markdown]
# which states are most susceptible to which types of natural disasters

# %%
d = combined_data[['state', 'incident_type']].groupby('state').describe()
top_states = d['incident_type'].sort_values(by='count', ascending=False).head(10)
print(d.head(10))
# Out:
#       incident_type
#               count unique        top freq
# state
# AK               11      5       Fire    4
# AL               65      4    Tornado   48
# AR              145      2      Flood  115
# AS                5      1    Typhoon    5
# AZ               16      1      Flood   16
# CA              187      6      Flood  123
# CO               93      3      Flood   65
# CT                2      1  Hurricane    2
# DE                4      2    Drought    3
# FL               66      5  Hurricane   27

# %% [markdown]
# Plotting the describe() function's count, unique, and frequency with  axis pair grid

# %%
d = combined_data[['state', 'incident_type']].groupby('state').describe()
sns.pairplot(d['incident_type'].reset_index(drop=True))

# %%
d['incident_type'].sort_values(by='count', ascending=False)['count'].head(10)
d['incident_type'].sort_values(by='freq', ascending=False)['freq'].head(10)
d['incident_type'].sort_values(by='unique', ascending=False)['unique'].head(10)
# Out:
# state
# TX    7
# CA    6
# AK    5
# FL    5
# MA    5
# HI    5
# MS    5
# NC    4
# AL    4
# WI    4
# Name: unique, dtype: object

# %%
#The state's highest risk

p = combined_data[['state', 'incident_type']].groupby('state').count()
p.reset_index(inplace=True)
p = p.sort_values(by='incident_type', ascending=False).head(10)
p
# Out:
#    state  incident_type
# 46    TX            695
# 14    IA            223
# 25    MN            200
# 18    KS            190
# 5     CA            187
# 47    VA            170
# 26    MO            158
# 2     AR            145
# 27    MS            125
# 45    TN            124
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def value_plot(df, y, figscale=1):
#   from matplotlib import pyplot as plt
#   df[y].plot(kind='line', figsize=(8 * figscale, 4 * figscale), title=y)
#   plt.gca().spines[['top', 'right']].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = value_plot(p, *['incident_type'], **{})
# chart
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def histogram(df, colname, num_bins=20, figscale=1):
#   from matplotlib import pyplot as plt
#   df[colname].plot(kind='hist', bins=num_bins, title=colname, figsize=(8*figscale, 4*figscale))
#   plt.gca().spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = histogram(p, *['incident_type'], **{})
# chart
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def value_plot(df, y, figscale=1):
#   from matplotlib import pyplot as plt
#   df[y].plot(kind='line', figsize=(8 * figscale, 4 * figscale), title=y)
#   plt.gca().spines[['top', 'right']].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = value_plot(p, *['incident_type'], **{})
# chart
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def histogram(df, colname, num_bins=20, figscale=1):
#   from matplotlib import pyplot as plt
#   df[colname].plot(kind='hist', bins=num_bins, title=colname, figsize=(8*figscale, 4*figscale))
#   plt.gca().spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = histogram(p, *['incident_type'], **{})
# chart

# %%
# Make the information a dictionary.

data = {
    'index': [46, 14, 25, 18, 5, 47, 26, 2, 27, 45],
    'state': ['TX', 'IA', 'MN', 'KS', 'CA', 'VA', 'MO', 'AR', 'MS', 'TN'],
    'incident_type': [695, 223, 200, 190, 187, 170, 158, 145, 125, 124]
}

# Make a DataFrame.

d = pd.DataFrame(data)

# Make the bar graph.
plt.figure(figsize=(16, 8))
sns.barplot(x="state", y="incident_type", data=d)
plt.xlabel('State')
plt.ylabel('Incident Type Count')
plt.title('Top 10 States by Incident Type Count')
plt.show()

# %% [markdown]
# Texas TX appears to be the state that is most susceptible to disasters.

# %%
print("Texas mostly faces:\n")
incident_types_in_Texas = combined_data[['state','incident_type']].groupby('state').max().loc['TX']
print(incident_types_in_Texas)
# Out:
# Texas mostly faces:
#
# incident_type    Tornado
# Name: TX, dtype: object

# %% [markdown]
# Texas report end

# %%
m = combined_data.query('state=="TX"')['fy_declared'].value_counts().reset_index()
m.columns = ['Fiscal Year', 'Incident Count']
m.head(10)
# Out:
#    Fiscal Year  Incident Count
# 0       1967.0              29
# 1       1966.0              27
# 2       1973.0              22
# 3       1970.0              18
# 4       1971.0              15
# 5       1972.0              13
# 6       1965.0               7
# 7       1968.0               5
# 8       1953.0               2
# 9       1954.0               1
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def value_plot(df, y, figscale=1):
#   from matplotlib import pyplot as plt
#   df[y].plot(kind='line', figsize=(8 * figscale, 4 * figscale), title=y)
#   plt.gca().spines[['top', 'right']].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = value_plot(_df_5, *['Fiscal Year'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def value_plot(df, y, figscale=1):
#   from matplotlib import pyplot as plt
#   df[y].plot(kind='line', figsize=(8 * figscale, 4 * figscale), title=y)
#   plt.gca().spines[['top', 'right']].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = value_plot(_df_6, *['Incident Count'], **{})
# chart
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def histogram(df, colname, num_bins=20, figscale=1):
#   from matplotlib import pyplot as plt
#   df[colname].plot(kind='hist', bins=num_bins, title=colname, figsize=(8*figscale, 4*figscale))
#   plt.gca().spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = histogram(_df_7, *['Fiscal Year'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def histogram(df, colname, num_bins=20, figscale=1):
#   from matplotlib import pyplot as plt
#   df[colname].plot(kind='hist', bins=num_bins, title=colname, figsize=(8*figscale, 4*figscale))
#   plt.gca().spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = histogram(_df_8, *['Incident Count'], **{})
# chart
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def scatter_plots(df, colname_pairs, figscale=1, alpha=.8):
#   from matplotlib import pyplot as plt
#   plt.figure(figsize=(len(colname_pairs) * 10 * figscale, 10 * figscale))
#   for plot_i, (x_colname, y_colname) in enumerate(colname_pairs, start=1):
#     ax = plt.subplot(1, len(colname_pairs), plot_i)
#     df.plot(kind='scatter', x=x_colname, y=y_colname, s=(32 * figscale), alpha=alpha, ax=ax)
#     ax.spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = scatter_plots(_df_9, *[[['Fiscal Year', 'Incident Count']]], **{})
# chart

# %% [markdown]
# According to the data, Texas reported events have varied significantly throughout the course of different fiscal years. Notably, there were much more instances reported in the years 1967 and 1966, with 29 and 27, respectively. In a similar vein, 22, 18, and 15 instances were reported in 1973, 1970, and 1971, respectively.
#
# It is interesting to note that there were only 2 and 1 events reported, respectively, in the years 1953 and 1954, which experienced significantly lower incident counts. This variation over time shows that there are different levels of natural catastrophe occurrences, with some years seeing more intense incidents and others seeing more milder circumstances. It is important to note that this analysis highlights the necessity for efficient disaster management and sheds light on the historical trends of natural disasters in Texas approaches to deal with these variations.

# %% [markdown]
# **Incident Counts by Fiscal Year in Texas between 1953 to 1973**

# %%
plt.figure(figsize=(20, 12))
sns.barplot(x='Fiscal Year', y='Incident Count', data=m.sort_values(by='Fiscal Year'))
plt.xlabel('Fiscal Year')
plt.ylabel('Incident Count')
plt.title('Incident Counts by Fiscal Year in Texas')
plt.show()

# %% [markdown]
# several reports between 1966 and 1973

# %%
unique_incident_types = combined_data.query('state == "TX" & fy_declared == 1973')['incident_type'].unique()
print(unique_incident_types)
# Out:
# ['Severe Storm' 'Flood']

# %%
unique_incident_types = combined_data.query('state == "TX" & fy_declared == 1966')['incident_type'].unique()
print(unique_incident_types)
# Out:
# ['Flood']

# %%
unique_incident_types = combined_data.query('state == "TX" & fy_declared == 1967')['incident_type'].unique()
print(unique_incident_types)
# Out:
# ['Hurricane']

# %%
unique_incident_types = combined_data.query('state == "TX" & fy_declared == 1970')['incident_type'].unique()
print(unique_incident_types)
# Out:
# ['Tornado' 'Hurricane']

# %% [markdown]
# The most disaster-prone places identified

# %%
print("Total Areas:", combined_data['designated_area'].nunique())
# Out:
# Total Areas: 1451

# %%
top_areas = combined_data[['designated_area', 'incident_type']].groupby('designated_area').count().sort_values(by='incident_type', ascending=False).head(15)
print(top_areas)
# Out:
#                      incident_type
# designated_area
# Statewide                      195
# Washington (County)             40
# Jackson (County)                34
# Jefferson (County)              34
# Lincoln (County)                33
# Franklin (County)               32
# Marion (County)                 29
# Montgomery (County)             27
# Clay (County)                   27
# Monroe (County)                 26
# Madison (County)                24
# Cass (County)                   22
# Pike (County)                   20
# Douglas (County)                20
# Harrison (County)               20

# %% [markdown]
# This shows that the state of DR has experienced the most natural disasters, however the designated Statewide County that has experienced the most disasters is not in Texas.

# %% [markdown]
# **By examining the dates when the most Statewide Disasters were reported,**

# %%
combined_data['declaration_date'] = pd.to_datetime(combined_data['declaration_date'])
combined_data['year'] = combined_data['declaration_date'].dt.year
combined_data['month'] = combined_data['declaration_date'].dt.month
combined_data['day'] = combined_data['declaration_date'].dt.day
combined_data['time'] = combined_data['declaration_date'].dt.time
del combined_data['declaration_date']

# %%
declaration_type_counts = combined_data['declaration_type'].value_counts()
print(declaration_type_counts)
# Out:
# DR    4196
# FM     135
# EM       1
# Name: declaration_type, dtype: int64

# %%
summary_stats = combined_data[['year', 'month', 'declaration_type']].groupby(['year', 'month']).describe()
print(summary_stats)
# Out:
#            declaration_type
#                       count unique top freq
# year month
# 1953 5                    3      1  DR    3
#      6                    6      1  DR    6
#      7                    1      1  DR    1
#      10                   2      1  DR    2
#      12                   1      1  DR    1
# ...                     ...    ...  ..  ...
# 2015 11                  22      1  DR   22
# 2016 2                   51      1  DR   51
#      3                   21      1  DR   21
#      4                   27      1  DR   27
#      6                   46      1  DR   46
#
# [201 rows x 4 columns]

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(x='declaration_type', y='year', data=combined_data)
plt.xlabel('Declaration Type')
plt.ylabel('Year')
plt.title('Boxplot of Declaration Year by Declaration Type')
plt.show()

# %%
plt.figure(figsize=(10, 5))
sns.barplot(x='index', y='declaration_type', data=combined_data['declaration_type'].value_counts().reset_index())
plt.xlabel('Declaration Type')
plt.ylabel('Count')
plt.title('Count of Declaration Types')
plt.show()

# %% [markdown]
# Observations about dates

# %%
result = combined_data[['year', 'month', 'day', 'declaration_type']].groupby(['year', 'month', 'day']).count()
result = result.reset_index().sort_values(by='declaration_type', ascending=False)
print(result)
# Out:
#      year  month  day  declaration_type
# 278  1972      6   23               234
# 209  1969      4   18               142
# 370  2011      7    1               122
# 305  1973      4   27               122
# 344  1974      4    4               115
# ..    ...    ...  ...               ...
# 142  1964      7    8                 1
# 141  1964      6    9                 1
# 140  1964      6    8                 1
# 29   1955      5   27                 1
# 0    1953      5    2                 1
#
# [427 rows x 4 columns]

# %% [markdown]
# The day of June 23, 1972, saw the largest number of catastrophes ever reported (234), according to records of disaster declarations. This significant date commemorates a crucial occasion when numerous disaster declarations were made. Other noteworthy dates include July 1, 2011, with 122 disaster announcements, and April 18, 1969, when 142 disaster declarations were reported. To better understand the nature and effects of the reported disasters, certain dates have been set aside for additional research. A closer look at the disaster declarations made on March 13, 2020, January 13, 1996, April 4, 2020, and September 11, 2005 has been highlighted as noteworthy dates that call for closer examination.

# %%
date = combined_data.query('year == 1972 & month == 6 & day == 23')['declaration_title'].value_counts()
print(date)
# Out:
# Tropical Storm Agnes    234
# Name: declaration_title, dtype: int64

# %%
# Considering that combined_data is the DataFrame
d = combined_data.query('year=={0} & month=={1}'.format(1970, 5))
declaration_counts = d['declaration_title'].value_counts()

if not declaration_counts.empty:
    plt.figure(figsize=(10, 6))
    sns.barplot(x=declaration_counts.index, y=declaration_counts.values)
    plt.xlabel('Declaration Title')
    plt.ylabel('Count')
    plt.title('Declaration Titles in May 1970')
    plt.xticks(rotation=0)
    plt.show()

# %%
# Considering combined_data in a DataFrame

m = combined_data.query('year == 1970 & month == 9')

plt.figure(figsize=(9, 8))
sns.countplot(x='declaration_title', data=m.sort_values(by='time'), hue='state')
plt.xlabel('Declaration Title')
plt.ylabel('Count')
plt.title('Declaration Titles in june 1970 by State')
plt.xticks(rotation=0)
plt.legend(title='State')
plt.show()

# %%
date_mask = (combined_data['year'] == 1953) & (combined_data['month'] == 5) & (combined_data['day'] == 2)
records_with_date = combined_data[date_mask]
print(records_with_date)
# Out:
#   fema_declaration_string  disaster_number state declaration_type  \
# 0                 DR-1-GA                1    GA               DR
#
#    fy_declared incident_type declaration_title  ih_program_declared  \
# 0       1953.0       Tornado           Tornado                    0
#
#    ia_program_declared  pa_program_declared  ...  designated_area  \
# 0                    1                    1  ...        Statewide
#
#   declaration_request_number last_ia_filing_date          last_refresh  \
# 0                    53013.0                 NaN  2023-03-18T13:22:03Z
#
#                                        hash  \
# 0  48af1afcc4535aa910ddb5b85eebe047dc703a6b
#
#                                      id  year  month  day      time
# 0  da5c8f17-c28f-4c41-8e06-fa8efc85aa4a  1953      5    2  00:00:00
#
# [1 rows x 26 columns]

# %%
date_mask = (combined_data['year'] == 1955) & (combined_data['month'] == 8) & (combined_data['day'] == 20)
records_with_date = combined_data[date_mask]
print(records_with_date)
# Out:
#    fema_declaration_string  disaster_number state declaration_type  \
# 37                DR-44-SC               44    SC               DR
# 38                DR-43-MA               43    MA               DR
# 39                DR-42-CT               42    CT               DR
# 40                DR-41-NJ               41    NJ               DR
# 41                DR-40-PA               40    PA               DR
# 42                DR-39-RI               39    RI               DR
#
#     fy_declared incident_type                    declaration_title  \
# 37       1955.0     Hurricane                           Hurricanes
# 38       1955.0     Hurricane                   Hurricane & Floods
# 39       1955.0     Hurricane  Hurricane, Torrential Rain & Floods
# 40       1955.0     Hurricane                   Hurricane & Floods
# 41       1955.0         Flood                       Floods & Rains
# 42       1955.0     Hurricane                    Hurricane & Flood
#
#     ih_program_declared  ia_program_declared  pa_program_declared  ...  \
# 37                    0                    1                    1  ...
# 38                    0                    1                    1  ...
# 39                    0                    1                    1  ...
# 40                    0                    1                    1  ...
# 41                    0                    1                    1  ...
# 42                    0                    1                    1  ...
#
#     designated_area declaration_request_number last_ia_filing_date  \
# 37        Statewide                    55016.0                 NaN
# 38        Statewide                    55014.0                 NaN
# 39        Statewide                    55013.0                 NaN
# 40        Statewide                    55012.0                 NaN
# 41        Statewide                    55011.0                 NaN
# 42        Statewide                    55010.0                 NaN
#
#             last_refresh                                      hash  \
# 37  2023-03-18T13:22:03Z  8f975d627fa28cff25845e2d09aaf25366a3927e
# 38  2023-03-18T13:22:03Z  780975b23575e9382828fcb43a9db9c23b6e717f
# 39  2023-03-18T13:22:03Z  b46bd864894312d5ff20919cd3f3e11893930a60
# 40  2023-03-18T13:22:03Z  2d2bfb33a32be1e6a82dbe83e38f80ab79394328
# 41  2023-03-18T13:22:03Z  7a014fa1f289cf883a805161966ec49a433268ce
# 42  2023-03-18T13:22:03Z  0a57ca730115bae04cadd9560d7491664847352f
#
#                                       id  year  month  day      time
# 37  ffd3e492-f328-46f1-aadf-cb9deac5a17a  1955      8   20  00:00:00
# 38  5a78f505-a544-49bb-af30-e2a8c0957c21  1955      8   20  00:00:00
# 39  06291e58-c2bb-4352-a22f-94b18636b3a4  1955      8   20  00:00:00
# 40  fe5edaab-74d7-4738-8c37-b1bf89eecc75  1955      8   20  00:00:00
# 41  e7a711fd-42ef-409b-9175-bd28864ef8eb  1955      8   20  00:00:00
# 42  8355bc32-7086-4198-a8b9-bac979e8f766  1955      8   20  00:00:00
#
# [6 rows x 26 columns]

# %%
date_mask = (combined_data['year'] == 2011) & (combined_data['month'] == 2) & (combined_data['day'] == 28)
records_with_date = combined_data[date_mask]
print(records_with_date)
# Out:
#   fema_declaration_string  disaster_number state declaration_type  \
# 0                     NaN             2862    TX               FM
# 1                     NaN             2863    TX               FM
# 2                     NaN             2864    TX               FM
# 3                     NaN             2865    TX               FM
#
#    fy_declared incident_type                declaration_title  \
# 0          NaN          Fire  Willow Creek South Fire Complex
# 1          NaN          Fire                     Matador Fire
# 2          NaN          Fire          Tanglewood Fire Complex
# 3          NaN          Fire            Mitchell Fire Complex
#
#    ih_program_declared  ia_program_declared  pa_program_declared  ...  \
# 0                    0                    0                    1  ...
# 1                    0                    0                    1  ...
# 2                    0                    0                    1  ...
# 3                    0                    0                    1  ...
#
#      designated_area declaration_request_number last_ia_filing_date  \
# 0    Potter (County)                        NaN                 NaN
# 1    Motley (County)                        NaN                 NaN
# 2   Randall (County)                        NaN                 NaN
# 3  Mitchell (County)                        NaN                 NaN
#
#   last_refresh  hash   id  year  month  day      time
# 0          NaN   NaN  NaN  2011      2   28  03:12:00
# 1          NaN   NaN  NaN  2011      2   28  03:25:00
# 2          NaN   NaN  NaN  2011      2   28  03:37:00
# 3          NaN   NaN  NaN  2011      2   28  05:55:00
#
# [4 rows x 26 columns]

# %%
date_mask = (combined_data['year'] == 2015) & (combined_data['month'] == 5) & (combined_data['day'] == 30)
records_with_date = combined_data[date_mask]
print(records_with_date)
# Out:
#     fema_declaration_string  disaster_number state declaration_type  \
# 334                     NaN             4223    TX               DR
# 335                     NaN             4223    TX               DR
# 336                     NaN             4223    TX               DR
# 337                     NaN             4223    TX               DR
# 338                     NaN             4223    TX               DR
# ..                      ...              ...   ...              ...
# 442                     NaN             4223    TX               DR
# 443                     NaN             4223    TX               DR
# 444                     NaN             4223    TX               DR
# 445                     NaN             4223    TX               DR
# 446                     NaN             4223    TX               DR
#
#      fy_declared    incident_type  \
# 334          NaN  Severe Storm(s)
# 335          NaN  Severe Storm(s)
# 336          NaN  Severe Storm(s)
# 337          NaN  Severe Storm(s)
# 338          NaN  Severe Storm(s)
# ..           ...              ...
# 442          NaN  Severe Storm(s)
# 443          NaN  Severe Storm(s)
# 444          NaN  Severe Storm(s)
# 445          NaN  Severe Storm(s)
# 446          NaN  Severe Storm(s)
#
#                                      declaration_title  ih_program_declared  \
# 334  Severe Storms, Tornadoes, Straight-Line Winds ...                    0
# 335  Severe Storms, Tornadoes, Straight-Line Winds ...                    0
# 336  Severe Storms, Tornadoes, Straight-Line Winds ...                    0
# 337  Severe Storms, Tornadoes, Straight-Line Winds ...                    0
# 338  Severe Storms, Tornadoes, Straight-Line Winds ...                    0
# ..                                                 ...                  ...
# 442  Severe Storms, Tornadoes, Straight-Line Winds ...                    1
# 443  Severe Storms, Tornadoes, Straight-Line Winds ...                    0
# 444  Severe Storms, Tornadoes, Straight-Line Winds ...                    1
# 445  Severe Storms, Tornadoes, Straight-Line Winds ...                    1
# 446  Severe Storms, Tornadoes, Straight-Line Winds ...                    1
#
#      ia_program_declared  pa_program_declared  ...      designated_area  \
# 334                    0                    1  ...      Archer (County)
# 335                    0                    1  ...    Atascosa (County)
# 336                    0                    1  ...      DeWitt (County)
# 337                    0                    1  ...    Callahan (County)
# 338                    0                    1  ...        Cass (County)
# ..                   ...                  ...  ...                  ...
# 442                    0                    1  ...       Milam (County)
# 443                    0                    1  ...      Wilson (County)
# 444                    0                    1  ...     Wichita (County)
# 445                    0                    1  ...   Van Zandt (County)
# 446                    0                    1  ...  Williamson (County)
#
#     declaration_request_number last_ia_filing_date last_refresh  hash   id  \
# 334                        NaN                 NaN          NaN   NaN  NaN
# 335                        NaN                 NaN          NaN   NaN  NaN
# 336                        NaN                 NaN          NaN   NaN  NaN
# 337                        NaN                 NaN          NaN   NaN  NaN
# 338                        NaN                 NaN          NaN   NaN  NaN
# ..                         ...                 ...          ...   ...  ...
# 442                        NaN                 NaN          NaN   NaN  NaN
# 443                        NaN                 NaN          NaN   NaN  NaN
# 444                        NaN                 NaN          NaN   NaN  NaN
# 445                        NaN                 NaN          NaN   NaN  NaN
# 446                        NaN                 NaN          NaN   NaN  NaN
#
#      year  month  day      time
# 334  2015      5   30  03:02:00
# 335  2015      5   30  03:02:00
# 336  2015      5   30  03:02:00
# 337  2015      5   30  03:02:00
# 338  2015      5   30  03:02:00
# ..    ...    ...  ...       ...
# 442  2015      5   30  03:02:00
# 443  2015      5   30  03:02:00
# 444  2015      5   30  03:02:00
# 445  2015      5   30  03:02:00
# 446  2015      5   30  03:02:00
#
# [113 rows x 26 columns]

# %% [markdown]
# situations when housing or individualized help was not offered
# **bold text**

# %%
m = d.query('ia_program_declared == "0" & ih_program_declared == "1" & pa_program_declared =="1"')
print("Filtered DataFrame Shape:", m.shape)

incident_type_counts = d.query('ia_program_declared == "5" & ih_program_declared == "08" & pa_program_declared == "05"')['incident_type'].value_counts()
print(incident_type_counts)
# Out:
# Filtered DataFrame Shape: (0, 26)
# Series([], Name: incident_type, dtype: int64)

# %% [markdown]
# Despite having reported disasters, these people did not receive any special treatment or support from any pertinent programs. It is assumed that they may have gone unnoticed for reasons that are outside the purview of our analysis.

# %%
# Establish a pivot table.

pt = combined_data.pivot_table(values='disaster_number', index='state', columns='year').fillna(0)

# Set the heatmap's size.
plt.figure(figsize=(12, 8))

# Produce the heatmap.

sns.heatmap(pt, cmap='coolwarm')

# Heatmap picture preservation
plt.savefig('heatmap.png')

#Show the heat map
plt.show()

# %% [markdown]
# The heatmap that results shows how frequently disasters occur in certain states over a range of years. Higher values are represented by warmer hues, which indicate that disasters are more likely to occur in certain states and years. Lower values are represented by cooler hues, which denote a lower frequency.
